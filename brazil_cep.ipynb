# %% [markdown]
# # This script gets a complete list of Brazilian zip codes (CEP)

# %%
import os
import json
import urllib
import requests
import pandas as pd
import sqlalchemy as db
from dotenv import load_dotenv
from datetime import date

# %%
# Load environment variables from .env file
load_dotenv()

# Access environment variable
db_local=os.environ['olist_db_local']
db_azure=os.environ['olist_db_azure']
back4app_id=os.environ['back4app_id']
back4app_key=os.environ['back4app_key']
export_path_local=os.environ['export_path_local']

# %%
# API call to back4app to retrieve count of Brazil CEP
where = urllib.parse.quote_plus("""
{
    "CEP": {
        "$exists": true
    }
}
""")
url = 'https://parseapi.back4app.com/classes/Brazilzipcode_CEP?count=1&limit=0&where=%s' % where
headers = {
    'X-Parse-Application-Id': back4app_id,
    'X-Parse-REST-API-Key': back4app_key
}
data = json.loads(requests.get(url, headers=headers).content.decode('utf-8'))
print(json.dumps(data, indent=2))
count_value = data["count"]
# Out:
# {
#   "results": [],
#   "count": 730321
# }

# %%
# API call to back4app to retrieve all Brazil CEP
# In 1000 rows each page

page_size = 1000
for i in range(0, count_value, page_size):
    url = f'https://parseapi.back4app.com/classes/Brazilzipcode_CEP?skip={i}&limit={1000}&order=CEP&excludeKeys=info,logradouro,numero'
    headers = {
        'X-Parse-Application-Id': back4app_id,
        'X-Parse-REST-API-Key': back4app_key
    }
    data = json.loads(requests.get(url, headers=headers).content.decode('utf-8'))
    filename = f'{export_path_local}page_{i // page_size + 1}.json'
    with open(filename, 'w') as outfile:
        json.dump(data, outfile, indent=4)
    print(f"Saved data from page {i // page_size + 1} to {filename}")

print("All pages retrieved and saved successfully.")
# Out:
# Saved data from page 1 to page_1.json
# Saved data from page 2 to page_2.json
# Saved data from page 3 to page_3.json
# Saved data from page 4 to page_4.json
# Saved data from page 5 to page_5.json
# Saved data from page 6 to page_6.json
# Saved data from page 7 to page_7.json
# Saved data from page 8 to page_8.json
# Saved data from page 9 to page_9.json
# Saved data from page 10 to page_10.json
# Saved data from page 11 to page_11.json
# Saved data from page 12 to page_12.json
# Saved data from page 13 to page_13.json
# Saved data from page 14 to page_14.json
# Saved data from page 15 to page_15.json
# Saved data from page 16 to page_16.json
# Saved data from page 17 to page_17.json
# Saved data from page 18 to page_18.json
# Saved data from page 19 to page_19.json
# Saved data from page 20 to page_20.json
# Saved data from page 21 to page_21.json
# Saved data from page 22 to page_22.json
# Saved data from page 23 to page_23.json
# Saved data from page 24 to page_24.json
# Saved data from page 25 to page_25.json
# Saved data from page 26 to page_26.json
# Saved data from page 27 to page_27.json
# Saved data from page 28 to page_28.json
# Saved data from page 29 to page_29.json
# Saved data from page 30 to page_30.json
# Saved data from page 31 to page_31.json
# Saved data from page 32 to page_32.json
# Saved data from page 33 to page_33.json
# Saved data from page 34 to page_34.json
# Saved data from page 35 to page_35.json
# Saved data from page 36 to page_36.json
# Saved data from page 37 to page_37.json
# Saved data from page 38 to page_38.json
# Saved data from page 39 to page_39.json
# Saved data from page 40 to page_40.json
# Saved data from page 41 to page_41.json
# Saved data from page 42 to page_42.json
# Saved data from page 43 to page_43.json
# Saved data from page 44 to page_44.json
# Saved data from page 45 to page_45.json
# Saved data from page 46 to page_46.json
# Saved data from page 47 to page_47.json
# Saved data from page 48 to page_48.json
# Saved data from page 49 to page_49.json
# Saved data from page 50 to page_50.json
# Saved data from page 51 to page_51.json
# Saved data from page 52 to page_52.json
# Saved data from page 53 to page_53.json
# Saved data from page 54 to page_54.json
# Saved data from page 55 to page_55.json
# Saved data from page 56 to page_56.json
# Saved data from page 57 to page_57.json
# Saved data from page 58 to page_58.json
# Saved data from page 59 to page_59.json
# Saved data from page 60 to page_60.json
# Saved data from page 61 to page_61.json
# Saved data from page 62 to page_62.json
# Saved data from page 63 to page_63.json
# Saved data from page 64 to page_64.json
# Saved data from page 65 to page_65.json
# Saved data from page 66 to page_66.json
# Saved data from page 67 to page_67.json
# Saved data from page 68 to page_68.json
# Saved data from page 69 to page_69.json
# Saved data from page 70 to page_70.json
# Saved data from page 71 to page_71.json
# Saved data from page 72 to page_72.json
# Saved data from page 73 to page_73.json
# Saved data from page 74 to page_74.json
# Saved data from page 75 to page_75.json
# Saved data from page 76 to page_76.json
# Saved data from page 77 to page_77.json
# Saved data from page 78 to page_78.json
# Saved data from page 79 to page_79.json
# Saved data from page 80 to page_80.json
# Saved data from page 81 to page_81.json
# Saved data from page 82 to page_82.json
# Saved data from page 83 to page_83.json
# Saved data from page 84 to page_84.json
# Saved data from page 85 to page_85.json
# Saved data from page 86 to page_86.json
# Saved data from page 87 to page_87.json
# Saved data from page 88 to page_88.json
# Saved data from page 89 to page_89.json
# Saved data from page 90 to page_90.json
# Saved data from page 91 to page_91.json
# Saved data from page 92 to page_92.json
# Saved data from page 93 to page_93.json
# Saved data from page 94 to page_94.json
# Saved data from page 95 to page_95.json
# Saved data from page 96 to page_96.json
# Saved data from page 97 to page_97.json
# Saved data from page 98 to page_98.json
# Saved data from page 99 to page_99.json
# Saved data from page 100 to page_100.json
# Saved data from page 101 to page_101.json
# Saved data from page 102 to page_102.json
# Saved data from page 103 to page_103.json
# Saved data from page 104 to page_104.json
# Saved data from page 105 to page_105.json
# Saved data from page 106 to page_106.json
# Saved data from page 107 to page_107.json
# Saved data from page 108 to page_108.json
# Saved data from page 109 to page_109.json
# Saved data from page 110 to page_110.json
# Saved data from page 111 to page_111.json
# Saved data from page 112 to page_112.json
# Saved data from page 113 to page_113.json
# Saved data from page 114 to page_114.json
# Saved data from page 115 to page_115.json
# Saved data from page 116 to page_116.json
# Saved data from page 117 to page_117.json
# Saved data from page 118 to page_118.json
# Saved data from page 119 to page_119.json
# Saved data from page 120 to page_120.json
# Saved data from page 121 to page_121.json
# Saved data from page 122 to page_122.json
# Saved data from page 123 to page_123.json
# Saved data from page 124 to page_124.json
# Saved data from page 125 to page_125.json
# Saved data from page 126 to page_126.json
# Saved data from page 127 to page_127.json
# Saved data from page 128 to page_128.json
# Saved data from page 129 to page_129.json
# Saved data from page 130 to page_130.json
# Saved data from page 131 to page_131.json
# Saved data from page 132 to page_132.json
# Saved data from page 133 to page_133.json
# Saved data from page 134 to page_134.json
# Saved data from page 135 to page_135.json
# Saved data from page 136 to page_136.json
# Saved data from page 137 to page_137.json
# Saved data from page 138 to page_138.json
# Saved data from page 139 to page_139.json
# Saved data from page 140 to page_140.json
# Saved data from page 141 to page_141.json
# Saved data from page 142 to page_142.json
# Saved data from page 143 to page_143.json
# Saved data from page 144 to page_144.json
# Saved data from page 145 to page_145.json
# Saved data from page 146 to page_146.json
# Saved data from page 147 to page_147.json
# Saved data from page 148 to page_148.json
# Saved data from page 149 to page_149.json
# Saved data from page 150 to page_150.json
# Saved data from page 151 to page_151.json
# Saved data from page 152 to page_152.json
# Saved data from page 153 to page_153.json
# Saved data from page 154 to page_154.json
# Saved data from page 155 to page_155.json
# Saved data from page 156 to page_156.json
# Saved data from page 157 to page_157.json
# Saved data from page 158 to page_158.json
# Saved data from page 159 to page_159.json
# Saved data from page 160 to page_160.json
# Saved data from page 161 to page_161.json
# Saved data from page 162 to page_162.json
# Saved data from page 163 to page_163.json
# Saved data from page 164 to page_164.json
# Saved data from page 165 to page_165.json
# Saved data from page 166 to page_166.json
# Saved data from page 167 to page_167.json
# Saved data from page 168 to page_168.json
# Saved data from page 169 to page_169.json
# Saved data from page 170 to page_170.json
# Saved data from page 171 to page_171.json
# Saved data from page 172 to page_172.json
# Saved data from page 173 to page_173.json
# Saved data from page 174 to page_174.json
# Saved data from page 175 to page_175.json
# Saved data from page 176 to page_176.json
# Saved data from page 177 to page_177.json
# Saved data from page 178 to page_178.json
# Saved data from page 179 to page_179.json
# Saved data from page 180 to page_180.json
# Saved data from page 181 to page_181.json
# Saved data from page 182 to page_182.json
# Saved data from page 183 to page_183.json
# Saved data from page 184 to page_184.json
# Saved data from page 185 to page_185.json
# Saved data from page 186 to page_186.json
# Saved data from page 187 to page_187.json
# Saved data from page 188 to page_188.json
# Saved data from page 189 to page_189.json
# Saved data from page 190 to page_190.json
# Saved data from page 191 to page_191.json
# Saved data from page 192 to page_192.json
# Saved data from page 193 to page_193.json
# Saved data from page 194 to page_194.json
# Saved data from page 195 to page_195.json
# Saved data from page 196 to page_196.json
# Saved data from page 197 to page_197.json
# Saved data from page 198 to page_198.json
# Saved data from page 199 to page_199.json
# Saved data from page 200 to page_200.json
# Saved data from page 201 to page_201.json
# Saved data from page 202 to page_202.json
# Saved data from page 203 to page_203.json
# Saved data from page 204 to page_204.json
# Saved data from page 205 to page_205.json
# Saved data from page 206 to page_206.json
# Saved data from page 207 to page_207.json
# Saved data from page 208 to page_208.json
# Saved data from page 209 to page_209.json
# Saved data from page 210 to page_210.json
# Saved data from page 211 to page_211.json
# Saved data from page 212 to page_212.json
# Saved data from page 213 to page_213.json
# Saved data from page 214 to page_214.json
# Saved data from page 215 to page_215.json
# Saved data from page 216 to page_216.json
# Saved data from page 217 to page_217.json
# Saved data from page 218 to page_218.json
# Saved data from page 219 to page_219.json
# Saved data from page 220 to page_220.json
# Saved data from page 221 to page_221.json
# Saved data from page 222 to page_222.json
# Saved data from page 223 to page_223.json
# Saved data from page 224 to page_224.json
# Saved data from page 225 to page_225.json
# Saved data from page 226 to page_226.json
# Saved data from page 227 to page_227.json
# Saved data from page 228 to page_228.json
# Saved data from page 229 to page_229.json
# Saved data from page 230 to page_230.json
# Saved data from page 231 to page_231.json
# Saved data from page 232 to page_232.json
# Saved data from page 233 to page_233.json
# Saved data from page 234 to page_234.json
# Saved data from page 235 to page_235.json
# Saved data from page 236 to page_236.json
# Saved data from page 237 to page_237.json
# Saved data from page 238 to page_238.json
# Saved data from page 239 to page_239.json
# Saved data from page 240 to page_240.json
# Saved data from page 241 to page_241.json
# Saved data from page 242 to page_242.json
# Saved data from page 243 to page_243.json
# Saved data from page 244 to page_244.json
# Saved data from page 245 to page_245.json
# Saved data from page 246 to page_246.json
# Saved data from page 247 to page_247.json
# Saved data from page 248 to page_248.json
# Saved data from page 249 to page_249.json
# Saved data from page 250 to page_250.json
# Saved data from page 251 to page_251.json
# Saved data from page 252 to page_252.json
# Saved data from page 253 to page_253.json
# Saved data from page 254 to page_254.json
# Saved data from page 255 to page_255.json
# Saved data from page 256 to page_256.json
# Saved data from page 257 to page_257.json
# Saved data from page 258 to page_258.json
# Saved data from page 259 to page_259.json
# Saved data from page 260 to page_260.json
# Saved data from page 261 to page_261.json
# Saved data from page 262 to page_262.json
# Saved data from page 263 to page_263.json
# Saved data from page 264 to page_264.json
# Saved data from page 265 to page_265.json
# Saved data from page 266 to page_266.json
# Saved data from page 267 to page_267.json
# Saved data from page 268 to page_268.json
# Saved data from page 269 to page_269.json
# Saved data from page 270 to page_270.json
# Saved data from page 271 to page_271.json
# Saved data from page 272 to page_272.json
# Saved data from page 273 to page_273.json
# Saved data from page 274 to page_274.json
# Saved data from page 275 to page_275.json
# Saved data from page 276 to page_276.json
# Saved data from page 277 to page_277.json
# Saved data from page 278 to page_278.json
# Saved data from page 279 to page_279.json
# Saved data from page 280 to page_280.json
# Saved data from page 281 to page_281.json
# Saved data from page 282 to page_282.json
# Saved data from page 283 to page_283.json
# Saved data from page 284 to page_284.json
# Saved data from page 285 to page_285.json
# Saved data from page 286 to page_286.json
# Saved data from page 287 to page_287.json
# Saved data from page 288 to page_288.json
# Saved data from page 289 to page_289.json
# Saved data from page 290 to page_290.json
# Saved data from page 291 to page_291.json
# Saved data from page 292 to page_292.json
# Saved data from page 293 to page_293.json
# Saved data from page 294 to page_294.json
# Saved data from page 295 to page_295.json
# Saved data from page 296 to page_296.json
# Saved data from page 297 to page_297.json
# Saved data from page 298 to page_298.json
# Saved data from page 299 to page_299.json
# Saved data from page 300 to page_300.json
# Saved data from page 301 to page_301.json
# Saved data from page 302 to page_302.json
# Saved data from page 303 to page_303.json
# Saved data from page 304 to page_304.json
# Saved data from page 305 to page_305.json
# Saved data from page 306 to page_306.json
# Saved data from page 307 to page_307.json
# Saved data from page 308 to page_308.json
# Saved data from page 309 to page_309.json
# Saved data from page 310 to page_310.json
# Saved data from page 311 to page_311.json
# Saved data from page 312 to page_312.json
# Saved data from page 313 to page_313.json
# Saved data from page 314 to page_314.json
# Saved data from page 315 to page_315.json
# Saved data from page 316 to page_316.json
# Saved data from page 317 to page_317.json
# Saved data from page 318 to page_318.json
# Saved data from page 319 to page_319.json
# Saved data from page 320 to page_320.json
# Saved data from page 321 to page_321.json
# Saved data from page 322 to page_322.json
# Saved data from page 323 to page_323.json
# Saved data from page 324 to page_324.json
# Saved data from page 325 to page_325.json
# Saved data from page 326 to page_326.json
# Saved data from page 327 to page_327.json
# Saved data from page 328 to page_328.json
# Saved data from page 329 to page_329.json
# Saved data from page 330 to page_330.json
# Saved data from page 331 to page_331.json
# Saved data from page 332 to page_332.json
# Saved data from page 333 to page_333.json
# Saved data from page 334 to page_334.json
# Saved data from page 335 to page_335.json
# Saved data from page 336 to page_336.json
# Saved data from page 337 to page_337.json
# Saved data from page 338 to page_338.json
# Saved data from page 339 to page_339.json
# Saved data from page 340 to page_340.json
# Saved data from page 341 to page_341.json
# Saved data from page 342 to page_342.json
# Saved data from page 343 to page_343.json
# Saved data from page 344 to page_344.json
# Saved data from page 345 to page_345.json
# Saved data from page 346 to page_346.json
# Saved data from page 347 to page_347.json
# Saved data from page 348 to page_348.json
# Saved data from page 349 to page_349.json
# Saved data from page 350 to page_350.json
# Saved data from page 351 to page_351.json
# Saved data from page 352 to page_352.json
# Saved data from page 353 to page_353.json
# Saved data from page 354 to page_354.json
# Saved data from page 355 to page_355.json
# Saved data from page 356 to page_356.json
# Saved data from page 357 to page_357.json
# Saved data from page 358 to page_358.json
# Saved data from page 359 to page_359.json
# Saved data from page 360 to page_360.json
# Saved data from page 361 to page_361.json
# Saved data from page 362 to page_362.json
# Saved data from page 363 to page_363.json
# Saved data from page 364 to page_364.json
# Saved data from page 365 to page_365.json
# Saved data from page 366 to page_366.json
# Saved data from page 367 to page_367.json
# Saved data from page 368 to page_368.json
# Saved data from page 369 to page_369.json
# Saved data from page 370 to page_370.json
# Saved data from page 371 to page_371.json
# Saved data from page 372 to page_372.json
# Saved data from page 373 to page_373.json
# Saved data from page 374 to page_374.json
# Saved data from page 375 to page_375.json
# Saved data from page 376 to page_376.json
# Saved data from page 377 to page_377.json
# Saved data from page 378 to page_378.json
# Saved data from page 379 to page_379.json
# Saved data from page 380 to page_380.json
# Saved data from page 381 to page_381.json
# Saved data from page 382 to page_382.json
# Saved data from page 383 to page_383.json
# Saved data from page 384 to page_384.json
# Saved data from page 385 to page_385.json
# Saved data from page 386 to page_386.json
# Saved data from page 387 to page_387.json
# Saved data from page 388 to page_388.json
# Saved data from page 389 to page_389.json
# Saved data from page 390 to page_390.json
# Saved data from page 391 to page_391.json
# Saved data from page 392 to page_392.json
# Saved data from page 393 to page_393.json
# Saved data from page 394 to page_394.json
# Saved data from page 395 to page_395.json
# Saved data from page 396 to page_396.json
# Saved data from page 397 to page_397.json
# Saved data from page 398 to page_398.json
# Saved data from page 399 to page_399.json
# Saved data from page 400 to page_400.json
# Saved data from page 401 to page_401.json
# Saved data from page 402 to page_402.json
# Saved data from page 403 to page_403.json
# Saved data from page 404 to page_404.json
# Saved data from page 405 to page_405.json
# Saved data from page 406 to page_406.json
# Saved data from page 407 to page_407.json
# Saved data from page 408 to page_408.json
# Saved data from page 409 to page_409.json
# Saved data from page 410 to page_410.json
# Saved data from page 411 to page_411.json
# Saved data from page 412 to page_412.json
# Saved data from page 413 to page_413.json
# Saved data from page 414 to page_414.json
# Saved data from page 415 to page_415.json
# Saved data from page 416 to page_416.json
# Saved data from page 417 to page_417.json
# Saved data from page 418 to page_418.json
# Saved data from page 419 to page_419.json
# Saved data from page 420 to page_420.json
# Saved data from page 421 to page_421.json
# Saved data from page 422 to page_422.json
# Saved data from page 423 to page_423.json
# Saved data from page 424 to page_424.json
# Saved data from page 425 to page_425.json
# Saved data from page 426 to page_426.json
# Saved data from page 427 to page_427.json
# Saved data from page 428 to page_428.json
# Saved data from page 429 to page_429.json
# Saved data from page 430 to page_430.json
# Saved data from page 431 to page_431.json
# Saved data from page 432 to page_432.json
# Saved data from page 433 to page_433.json
# Saved data from page 434 to page_434.json
# Saved data from page 435 to page_435.json
# Saved data from page 436 to page_436.json
# Saved data from page 437 to page_437.json
# Saved data from page 438 to page_438.json
# Saved data from page 439 to page_439.json
# Saved data from page 440 to page_440.json
# Saved data from page 441 to page_441.json
# Saved data from page 442 to page_442.json
# Saved data from page 443 to page_443.json
# Saved data from page 444 to page_444.json
# Saved data from page 445 to page_445.json
# Saved data from page 446 to page_446.json
# Saved data from page 447 to page_447.json
# Saved data from page 448 to page_448.json
# Saved data from page 449 to page_449.json
# Saved data from page 450 to page_450.json
# Saved data from page 451 to page_451.json
# Saved data from page 452 to page_452.json
# Saved data from page 453 to page_453.json
# Saved data from page 454 to page_454.json
# Saved data from page 455 to page_455.json
# Saved data from page 456 to page_456.json
# Saved data from page 457 to page_457.json
# Saved data from page 458 to page_458.json
# Saved data from page 459 to page_459.json
# Saved data from page 460 to page_460.json
# Saved data from page 461 to page_461.json
# Saved data from page 462 to page_462.json
# Saved data from page 463 to page_463.json
# Saved data from page 464 to page_464.json
# Saved data from page 465 to page_465.json
# Saved data from page 466 to page_466.json
# Saved data from page 467 to page_467.json
# Saved data from page 468 to page_468.json
# Saved data from page 469 to page_469.json
# Saved data from page 470 to page_470.json
# Saved data from page 471 to page_471.json
# Saved data from page 472 to page_472.json
# Saved data from page 473 to page_473.json
# Saved data from page 474 to page_474.json
# Saved data from page 475 to page_475.json
# Saved data from page 476 to page_476.json
# Saved data from page 477 to page_477.json
# Saved data from page 478 to page_478.json
# Saved data from page 479 to page_479.json
# Saved data from page 480 to page_480.json
# Saved data from page 481 to page_481.json
# Saved data from page 482 to page_482.json
# Saved data from page 483 to page_483.json
# Saved data from page 484 to page_484.json
# Saved data from page 485 to page_485.json
# Saved data from page 486 to page_486.json
# Saved data from page 487 to page_487.json
# Saved data from page 488 to page_488.json
# Saved data from page 489 to page_489.json
# Saved data from page 490 to page_490.json
# Saved data from page 491 to page_491.json
# Saved data from page 492 to page_492.json
# Saved data from page 493 to page_493.json
# Saved data from page 494 to page_494.json
# Saved data from page 495 to page_495.json
# Saved data from page 496 to page_496.json
# Saved data from page 497 to page_497.json
# Saved data from page 498 to page_498.json
# Saved data from page 499 to page_499.json
# Saved data from page 500 to page_500.json
# Saved data from page 501 to page_501.json
# Saved data from page 502 to page_502.json
# Saved data from page 503 to page_503.json
# Saved data from page 504 to page_504.json
# Saved data from page 505 to page_505.json
# Saved data from page 506 to page_506.json
# Saved data from page 507 to page_507.json
# Saved data from page 508 to page_508.json
# Saved data from page 509 to page_509.json
# Saved data from page 510 to page_510.json
# Saved data from page 511 to page_511.json
# Saved data from page 512 to page_512.json
# Saved data from page 513 to page_513.json
# Saved data from page 514 to page_514.json
# Saved data from page 515 to page_515.json
# Saved data from page 516 to page_516.json
# Saved data from page 517 to page_517.json
# Saved data from page 518 to page_518.json
# Saved data from page 519 to page_519.json
# Saved data from page 520 to page_520.json
# Saved data from page 521 to page_521.json
# Saved data from page 522 to page_522.json
# Saved data from page 523 to page_523.json
# Saved data from page 524 to page_524.json
# Saved data from page 525 to page_525.json
# Saved data from page 526 to page_526.json
# Saved data from page 527 to page_527.json
# Saved data from page 528 to page_528.json
# Saved data from page 529 to page_529.json
# Saved data from page 530 to page_530.json
# Saved data from page 531 to page_531.json
# Saved data from page 532 to page_532.json
# Saved data from page 533 to page_533.json
# Saved data from page 534 to page_534.json
# Saved data from page 535 to page_535.json
# Saved data from page 536 to page_536.json
# Saved data from page 537 to page_537.json
# Saved data from page 538 to page_538.json
# Saved data from page 539 to page_539.json
# Saved data from page 540 to page_540.json
# Saved data from page 541 to page_541.json
# Saved data from page 542 to page_542.json
# Saved data from page 543 to page_543.json
# Saved data from page 544 to page_544.json
# Saved data from page 545 to page_545.json
# Saved data from page 546 to page_546.json
# Saved data from page 547 to page_547.json
# Saved data from page 548 to page_548.json
# Saved data from page 549 to page_549.json
# Saved data from page 550 to page_550.json
# Saved data from page 551 to page_551.json
# Saved data from page 552 to page_552.json
# Saved data from page 553 to page_553.json
# Saved data from page 554 to page_554.json
# Saved data from page 555 to page_555.json
# Saved data from page 556 to page_556.json
# Saved data from page 557 to page_557.json
# Saved data from page 558 to page_558.json
# Saved data from page 559 to page_559.json
# Saved data from page 560 to page_560.json
# Saved data from page 561 to page_561.json
# Saved data from page 562 to page_562.json
# Saved data from page 563 to page_563.json
# Saved data from page 564 to page_564.json
# Saved data from page 565 to page_565.json
# Saved data from page 566 to page_566.json
# Saved data from page 567 to page_567.json
# Saved data from page 568 to page_568.json
# Saved data from page 569 to page_569.json
# Saved data from page 570 to page_570.json
# Saved data from page 571 to page_571.json
# Saved data from page 572 to page_572.json
# Saved data from page 573 to page_573.json
# Saved data from page 574 to page_574.json
# Saved data from page 575 to page_575.json
# Saved data from page 576 to page_576.json
# Saved data from page 577 to page_577.json
# Saved data from page 578 to page_578.json
# Saved data from page 579 to page_579.json
# Saved data from page 580 to page_580.json
# Saved data from page 581 to page_581.json
# Saved data from page 582 to page_582.json
# Saved data from page 583 to page_583.json
# Saved data from page 584 to page_584.json
# Saved data from page 585 to page_585.json
# Saved data from page 586 to page_586.json
# Saved data from page 587 to page_587.json
# Saved data from page 588 to page_588.json
# Saved data from page 589 to page_589.json
# Saved data from page 590 to page_590.json
# Saved data from page 591 to page_591.json
# Saved data from page 592 to page_592.json
# Saved data from page 593 to page_593.json
# Saved data from page 594 to page_594.json
# Saved data from page 595 to page_595.json
# Saved data from page 596 to page_596.json
# Saved data from page 597 to page_597.json
# Saved data from page 598 to page_598.json
# Saved data from page 599 to page_599.json
# Saved data from page 600 to page_600.json
# Saved data from page 601 to page_601.json
# Saved data from page 602 to page_602.json
# Saved data from page 603 to page_603.json
# Saved data from page 604 to page_604.json
# Saved data from page 605 to page_605.json
# Saved data from page 606 to page_606.json
# Saved data from page 607 to page_607.json
# Saved data from page 608 to page_608.json
# Saved data from page 609 to page_609.json
# Saved data from page 610 to page_610.json
# Saved data from page 611 to page_611.json
# Saved data from page 612 to page_612.json
# Saved data from page 613 to page_613.json
# Saved data from page 614 to page_614.json
# Saved data from page 615 to page_615.json
# Saved data from page 616 to page_616.json
# Saved data from page 617 to page_617.json
# Saved data from page 618 to page_618.json
# Saved data from page 619 to page_619.json
# Saved data from page 620 to page_620.json
# Saved data from page 621 to page_621.json
# Saved data from page 622 to page_622.json
# Saved data from page 623 to page_623.json
# Saved data from page 624 to page_624.json
# Saved data from page 625 to page_625.json
# Saved data from page 626 to page_626.json
# Saved data from page 627 to page_627.json
# Saved data from page 628 to page_628.json
# Saved data from page 629 to page_629.json
# Saved data from page 630 to page_630.json
# Saved data from page 631 to page_631.json
# Saved data from page 632 to page_632.json
# Saved data from page 633 to page_633.json
# Saved data from page 634 to page_634.json
# Saved data from page 635 to page_635.json
# Saved data from page 636 to page_636.json
# Saved data from page 637 to page_637.json
# Saved data from page 638 to page_638.json
# Saved data from page 639 to page_639.json
# Saved data from page 640 to page_640.json
# Saved data from page 641 to page_641.json
# Saved data from page 642 to page_642.json
# Saved data from page 643 to page_643.json
# Saved data from page 644 to page_644.json
# Saved data from page 645 to page_645.json
# Saved data from page 646 to page_646.json
# Saved data from page 647 to page_647.json
# Saved data from page 648 to page_648.json
# Saved data from page 649 to page_649.json
# Saved data from page 650 to page_650.json
# Saved data from page 651 to page_651.json
# Saved data from page 652 to page_652.json
# Saved data from page 653 to page_653.json
# Saved data from page 654 to page_654.json
# Saved data from page 655 to page_655.json
# Saved data from page 656 to page_656.json
# Saved data from page 657 to page_657.json
# Saved data from page 658 to page_658.json
# Saved data from page 659 to page_659.json
# Saved data from page 660 to page_660.json
# Saved data from page 661 to page_661.json
# Saved data from page 662 to page_662.json
# Saved data from page 663 to page_663.json
# Saved data from page 664 to page_664.json
# Saved data from page 665 to page_665.json
# Saved data from page 666 to page_666.json
# Saved data from page 667 to page_667.json
# Saved data from page 668 to page_668.json
# Saved data from page 669 to page_669.json
# Saved data from page 670 to page_670.json
# Saved data from page 671 to page_671.json
# Saved data from page 672 to page_672.json
# Saved data from page 673 to page_673.json
# Saved data from page 674 to page_674.json
# Saved data from page 675 to page_675.json
# Saved data from page 676 to page_676.json
# Saved data from page 677 to page_677.json
# Saved data from page 678 to page_678.json
# Saved data from page 679 to page_679.json
# Saved data from page 680 to page_680.json
# Saved data from page 681 to page_681.json
# Saved data from page 682 to page_682.json
# Saved data from page 683 to page_683.json
# Saved data from page 684 to page_684.json
# Saved data from page 685 to page_685.json
# Saved data from page 686 to page_686.json
# Saved data from page 687 to page_687.json
# Saved data from page 688 to page_688.json
# Saved data from page 689 to page_689.json
# Saved data from page 690 to page_690.json
# Saved data from page 691 to page_691.json
# Saved data from page 692 to page_692.json
# Saved data from page 693 to page_693.json
# Saved data from page 694 to page_694.json
# Saved data from page 695 to page_695.json
# Saved data from page 696 to page_696.json
# Saved data from page 697 to page_697.json
# Saved data from page 698 to page_698.json
# Saved data from page 699 to page_699.json
# Saved data from page 700 to page_700.json
# Saved data from page 701 to page_701.json
# Saved data from page 702 to page_702.json
# Saved data from page 703 to page_703.json
# Saved data from page 704 to page_704.json
# Saved data from page 705 to page_705.json
# Saved data from page 706 to page_706.json
# Saved data from page 707 to page_707.json
# Saved data from page 708 to page_708.json
# Saved data from page 709 to page_709.json
# Saved data from page 710 to page_710.json
# Saved data from page 711 to page_711.json
# Saved data from page 712 to page_712.json
# Saved data from page 713 to page_713.json
# Saved data from page 714 to page_714.json
# Saved data from page 715 to page_715.json
# Saved data from page 716 to page_716.json
# Saved data from page 717 to page_717.json
# Saved data from page 718 to page_718.json
# Saved data from page 719 to page_719.json
# Saved data from page 720 to page_720.json
# Saved data from page 721 to page_721.json
# Saved data from page 722 to page_722.json
# Saved data from page 723 to page_723.json
# Saved data from page 724 to page_724.json
# Saved data from page 725 to page_725.json
# Saved data from page 726 to page_726.json
# Saved data from page 727 to page_727.json
# Saved data from page 728 to page_728.json
# Saved data from page 729 to page_729.json
# Saved data from page 730 to page_730.json
# Saved data from page 731 to page_731.json
# All pages retrieved and saved successfully.

# %%
# Define the page size and the range for your loop
page_size = 1000
num_pages = i // page_size + 1
all_data = pd.DataFrame()

# Loop through the number of pages you have
for n in range(num_pages):
    # Read each JSON file
    filename = f'{export_path_local}page_{n+1}.json'
    with open(filename, 'r') as file:
        data = json.load(file)
        # Convert the JSON data to a DataFrame
        df = pd.DataFrame(data['results'])  # Update 'results' if your data has a different key
        # Append the DataFrame to the all_data DataFrame
        all_data = pd.concat([all_data, df], ignore_index=True)

# Now `all_data` contains all the data from the JSON files in one DataFrame
all_data.describe()
# Out:
#           objectId       CEP     cidade  estado  bairro  \
# count       730321    730321     730321  730321  730321
# unique      730321    730261      10162      73   18926
# top     b74XHFEeVf  70830016  São Paulo      SP  Centro
# freq             1         3      57081  185528   31337
#
#                        createdAt                 updatedAt
# count                     730321                    730321
# unique                     51631                     51631
# top     2019-12-17T20:54:09.620Z  2019-12-17T20:54:09.620Z
# freq                          20                        20

# %%
# Peek at data
all_data.info()
all_data.tail(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730321 entries, 0 to 730320
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   objectId   730321 non-null  object
#  1   CEP        730321 non-null  object
#  2   cidade     730321 non-null  object
#  3   estado     730321 non-null  object
#  4   bairro     730321 non-null  object
#  5   createdAt  730321 non-null  object
#  6   updatedAt  730321 non-null  object
# dtypes: object(7)
# memory usage: 39.0+ MB
#           objectId       CEP                                       cidade  \
# 730301  y9Usp35QoD  99951000                       Vila Campos (Tapejara)
# 730302  IyW5YCwCVg  99952000                         Santa Cecília do Sul
# 730303  8Z54gfYvGm  99952974                         Santa Cecília do Sul
# 730304  pcWdjzOgPB  99955000                                 Vila Lângaro
# 730305  cl8WHtojoM  99955971                                 Vila Lângaro
# 730306  xnwDF8aX46  99960000                                      Charrua
# 730307  I5xskE7j6F  99960975                                      Charrua
# 730308  TTIR8U7H4F  99965000                                   Água Santa
# 730309  VYBgItkXjj  99965971                                   Água Santa
# 730310  js3khuwG4r  99967000                  Engenho Grande (Água Santa)
# 730311  bPA2m0yAVf  99968000  Santo Antonio dos Pinheirinhos (Água Santa)
# 730312  1ykigIbhUi  99969000                     São Caetano (Água Santa)
# 730313  ulLaMqUQAd  99970000                                      Ciríaco
# 730314  6dM308YBjw  99970970                                      Ciríaco
# 730315  wm2Q8a0nKA  99975000                     São João Bosco (Ciríaco)
# 730316  WOrSuSOnE5  99975970                     São João Bosco (Ciríaco)
# 730317  aVrlgb4NXF  99978000                        Cruzaltinha (Ciríaco)
# 730318  2EJcbKQ0KH  99980000                              David Canabarro
# 730319  qX9XoZxr4O  99980970                              David Canabarro
# 730320  s4KkEeflXk  99980974                              David Canabarro
#
#                 estado                                  bairro  \
# 730301  RS  - Distrito
# 730302              RS
# 730303              RS                                  Centro
# 730304              RS
# 730305              RS                                  Centro
# 730306              RS
# 730307              RS                                  Centro
# 730308              RS
# 730309              RS                                  Centro
# 730310  RS  - Distrito
# 730311  RS  - Distrito
# 730312  RS  - Distrito
# 730313              RS
# 730314              RS                                  Centro
# 730315  RS  - Distrito
# 730316  RS  - Distrito                                  Centro
# 730317  RS  - Distrito
# 730318              RS
# 730319              RS                                  Centro
# 730320              RS  Capela São José do Capingui (Distrito)
#
#                        createdAt                 updatedAt
# 730301  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730302  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730303  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730304  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730305  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730306  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730307  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730308  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730309  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730310  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730311  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730312  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730313  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730314  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730315  2019-12-17T21:24:00.262Z  2019-12-17T21:24:00.262Z
# 730316  2019-12-17T21:24:00.630Z  2019-12-17T21:24:00.630Z
# 730317  2019-12-17T21:24:00.630Z  2019-12-17T21:24:00.630Z
# 730318  2019-12-17T21:24:00.630Z  2019-12-17T21:24:00.630Z
# 730319  2019-12-17T21:24:00.630Z  2019-12-17T21:24:00.630Z
# 730320  2019-12-17T21:24:00.630Z  2019-12-17T21:24:00.630Z

# %%
# Remove created and updated columns
all_data.drop(['createdAt', 'updatedAt'], axis=1, inplace=True)

# %%
# Rename columns
column_mapping = {
    'objectId': 'id',
    'CEP': 'cep',
    'cidade': 'city',
    'estado': 'state',
    'bairro': 'district'
}

all_data.rename(columns=column_mapping, inplace=True)
all_data.head()
# Out:
#            id       cep       city state district
# 0  b74XHFEeVf  01001000  São Paulo    SP       Sé
# 1  xCkm4Fn1PB  01001001  São Paulo    SP       Sé
# 2  ZhcbIFOMrv  01001010  São Paulo    SP       Sé
# 3  2fEuvsYM9J  01001900  São Paulo    SP       Sé
# 4  flKyzUR2tU  01001901  São Paulo    SP       Sé

# %%
# Create a new col containing only the first 5 digits of the zip code
all_data['zip_code_prefix'] = all_data['cep'].str[:5]

# %%
print(all_data['state'].unique())
# Out:
# ['SP' 'SP  - Distrito' 'SP  - Povoado' 'RJ' 'RJ  - Distrito'
#  'RJ  - Povoado' 'ES' 'ES  - Distrito' 'ES  - Povoado' 'MG'
#  'MG  - Distrito' 'MG  - Povoado' 'BA' 'BA  - Distrito' 'BA  - Povoado'
#  'SE' 'SE  - Distrito' 'PE' 'PE  - Povoado' 'PE  - Distrito' 'AL'
#  'AL  - Povoado' 'AL  - Distrito' 'PB' 'PB  - Distrito' 'PB  - Povoado'
#  'RN' 'RN  - Distrito' 'RN  - Povoado' 'CE' 'CE  - Distrito'
#  'CE  - Povoado' 'PI' 'PI  - Povoado' 'MA' 'MA  - Distrito'
#  'MA  - Povoado' 'PA' 'PA  - Distrito' 'PA  - Povoado' 'AP'
#  'AP  - Povoado' 'AP  - Distrito' 'AM' 'AM  - Distrito' 'AM  - Povoado'
#  'RR' 'RR  - Distrito' 'AC' 'AC  - Distrito' 'DF' 'GO' 'GO  - Distrito'
#  'GO  - Povoado' 'RO' 'RO  - Distrito' 'RO  - Povoado' 'TO'
#  'TO  - Distrito' 'TO  - Povoado' 'MT' 'MT  - Povoado' 'MT  - Distrito'
#  'MS' 'MS  - Distrito' 'PR' 'PR  - Povoado' 'PR  - Distrito' 'SC'
#  'SC  - Distrito' 'RS' 'RS  - Distrito' 'RS  - Povoado']

# %%
subset = ['cep', 'city', 'state']
loc_dupe = all_data.duplicated(subset = subset, keep = False)
all_data[loc_dupe].sort_values(by = 'cep')
# Out:
#                 id       cep       city state       district zip_code_prefix
# 45510   3BTjxysVUQ  05675050  São Paulo    SP  Cidade Jardim           05675
# 45511   C40XUpM3qB  05675050  São Paulo    SP  Cidade Jardim           05675
# 45512   VhP73TXQx1  05675060  São Paulo    SP  Cidade Jardim           05675
# 45513   jQySQmJrrq  05675060  São Paulo    SP  Cidade Jardim           05675
# 45514   xKBw8qSEL0  05675070  São Paulo    SP  Cidade Jardim           05675
# ...            ...       ...        ...   ...            ...             ...
# 520371  tF9F1Fd6Iw  70830104   Brasília    DF      Asa Norte           70830
# 520373  PFjr1KBgFy  70830104   Brasília    DF      Asa Norte           70830
# 520375  WCsOX0ry9m  70830105   Brasília    DF      Asa Norte           70830
# 520374  WBj0JqeBmm  70830105   Brasília    DF      Asa Norte           70830
# 520376  xBV6CTg8Rq  70830105   Brasília    DF      Asa Norte           70830
#
# [100 rows x 6 columns]

# %%
# Remove dupes
all_data = all_data.drop_duplicates(subset = subset, keep = 'first').reset_index(drop = True)
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730261 entries, 0 to 730260
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               730261 non-null  object
#  1   cep              730261 non-null  object
#  2   city             730261 non-null  object
#  3   state            730261 non-null  object
#  4   district         730261 non-null  object
#  5   zip_code_prefix  730261 non-null  object
# dtypes: object(6)
# memory usage: 33.4+ MB

# %%
# Split the 'state' column by the ' - ' delimiter
all_data[['state', 'state_1']] = all_data['state'].str.split(' - ', expand=True)

# %%
all_data.head()
# Out:
#            id       cep       city state district zip_code_prefix state_1
# 0  b74XHFEeVf  01001000  São Paulo    SP       Sé           01001    None
# 1  xCkm4Fn1PB  01001001  São Paulo    SP       Sé           01001    None
# 2  ZhcbIFOMrv  01001010  São Paulo    SP       Sé           01001    None
# 3  2fEuvsYM9J  01001900  São Paulo    SP       Sé           01001    None
# 4  flKyzUR2tU  01001901  São Paulo    SP       Sé           01001    None

# %%
print(all_data['state_1'].unique())
# Out:
# [None 'Distrito' 'Povoado']

# %%
# Export to .csv file
from datetime import date
today = date.today()
all_data.to_csv(f'{export_path_local}cep_{today}.csv')

# %% [markdown]
# # Export to DB

# %%
# Connect to DB
engine = db.create_engine(db_azure)
conn = engine.raw_connection()

# %%
# Create new table in PostgreSQL
commands = ('''CREATE TABLE IF NOT EXISTS cep(
);''')

# Initialize connection to PostgreSQL
cur = conn.cursor()

# Create cursor to execute SQL commands
#for command in commands:
cur.execute(commands)

# Commit changes
conn.commit()

# %%
# Copy data to table
all_data.to_sql(name= 'cep', con = engine, if_exists= 'replace')
# Out:
# 261

# %%
# Close communication with server
cur.close()
conn.close()
